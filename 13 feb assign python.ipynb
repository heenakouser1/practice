# %% [markdown]
# ### Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %%
# we can define custom exceptions by creating a new class that is derived from the built-in Exception class.
#  All Exceptions inherit the parent Exception Class, which we shall also inherit when creating our class.

# %% [markdown]
# ### Q2 Write a python program to print Python Exception Hierarchy.What happens if exception is not handled ? explain with an example

# %%
import inspect

def treeclass(cls,ind=0):
    print('-'*ind,cls.__name__)
    
    for i in cls.__subclasses__():
        treeclass(i,ind+3)
    print('hierarchy for bulit-in exceptions')
    
inspect.getclasstree(inspect.getmro(BaseException))

treeclass(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# hierarchy for bulit-in exceptions
# --------- MultipartConversionError
# hierarchy for bulit-in exceptions
# hierarchy for bulit-in exceptions
# ------ StopAsyncIteration
# hierarchy for bulit-in exceptions
# ------ StopIteration
# hierarchy for bulit-in exceptions
# ------ ImportError
# --------- ModuleNotFoundError
# hierarchy for bulit-in exceptions
# --------- ZipImportError
# hierarchy for bulit-in exceptions
# hierarchy for bulit-in exceptions
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# hierarchy for bulit-in exceptions
# ------------ ConnectionAbortedError
# hierarchy for bulit-in exceptions
# ------------ ConnectionRefusedError
# hierarchy for bulit-in exceptions
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# hierarchy for bulit-in exceptions
# hierarchy for bulit-in exceptions
# hierarchy for bulit-in exceptions
# ...

# %%
# Python will throw an exception error. This exception error will crash the program if it is unhandled

# in below program,it directly throws an error and stop the excution with executing further, all though program is syntatically correct


a=0
def check(a):
    if a/0:
        print('there is a issue')
    else:
        b=a+10

check(10)

# if we use try and catch bloack, exceptions are handled and program continue to run
a=0
try:
    def check(a):
        if a/0:
            print('there is a issue')
        else:
            b=a+10

    check(10)
except Exception as e:
    print(e)

# %% [markdown]
# ### Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
# The ArithmeticError exception class serves as a base class for
# those built-in exceptions that are raised due to various arithmetic
# errors like OverflowError, ZeroDivisionError, FloatingPointError

# %%
#Zerodivsionerror

try:
    a=10
    a/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
#OverflowError
import math

x=int(input('enter the exponential number'))
try:
    print('entered number is ',x)
    y=math.exp(x)
except OverflowError as e:
          print(e)
# Out:
# enter the exponential number 5999
# entered number is  5999
# math range error

# %%
# FloatingPointError
import numpy as np

try:
  with np.errstate(invalid='raise'):
       np.sqrt(-1)
except FloatingPointError as e:
  print("Caught FloatingPointError")
# Out:
# Caught FloatingPointError

# %% [markdown]
# ### Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
# LookupError Exception is the Base class for errors raised when something can’t be found. 
# The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.

# %%
# An IndexError is raised when a sequence reference is out of range

l=[1,2,4]

try:
    l[3]
except IndexError as e:
    print(e)

# %%
#Key error

ages = {'Jim': 30, 'Pam': 28, 'Kevin': 33}
person = input('Get age for: ')

try:
    print(f'{person} is {ages[person]} years old.')
except KeyError:
    print(f"{person}'s age is unknown.")
# Out:
# Get age for:  78
# 78's age is unknown.

# %% [markdown]
# ### Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
# import error is class exceptions, which is used to check whether the module imported is avalaible or not
# ModuleNotFoundError is exceptions accors when we import a module but that is not avliable

try:
    import pwskills
except ModuleNotFoundError as e:
    print(e)
# Out:
# No module named 'pwskills'

# %% [markdown]
# ### Q6. List down some best practices for exception handling in python.

# %%
# 1. Use a specific exception
# 2. Print a proper message
# 3. Try to log the exception
# 4. Always avoid using the multiple exception
# 5. Make a proper documentation of exception
# 6. Clean up the resources
