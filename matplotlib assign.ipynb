# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# ### Matplotlib.

# %%
# Matplotlib is visualization library used to data analyse through graphs
# Below are the graphs used 
# scatterplot
# bar
# histogram
# box
# line

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# ### plot a scatter plot.

# %%
# Scatterplot is a visual representation of two variables. 
# its is relationship between two variables

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
### Note: Also add title, xlabel, and ylabel to the plot.

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r',alpha=0.9,marker='x')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('scatter plot between x and y')
plt.grid()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# ### Use the following data:

# %%
# The matplotlib.pyplot.subplots() method provides a way to plot multiple plots on a single figure.
# Given the number of rows and columns, it returns a tuple (fig, ax), giving a single figure fig with an array of axes ax

# %%
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
# bar plot is used to get the graphical represenattion of categorical data.

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
box=[box1,box2]

# %%
# box plot is graphical representation of data, Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups

# %%
plt.boxplot(box,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8720167b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f872019c0a0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f8720167820>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f872019c4c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f872019c760>,
# ...
#  'means': []}
